# %% [markdown]
# # Assessing the Locations of linkNYC Stations
# ### The goal is to assess wheather the location of the linkNYC access points is optimal to guarantee a more "democratic" access to the internet.¶

# %%
__author__ = 'Solution by Linda Jaber, CUSP NYU 2018, Principles of Urban Informatics'
from __future__ import print_function

import sys
import os
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt
# %pylab inline


import requests
import json
import io

import shapely
from fiona.crs import from_epsg
import pysal as ps

pylab.rcParams['figure.figsize'] = 12, 8
pylab.rcParams['figure.dpi'] = 100

# %%
PUIdata = os.getenv('PUIDATA')
if PUIdata is None:
    os.environ['PUIDATA']='%s/PUIdata'%os.getenv('HOME')
    PUIdata = os.getenv('PUIDATA')
print('PUIdata: ', PUIdata)

# %% [markdown]
# ### 1. PUMA : Public Use Microdata Area
# ### 1.1 Downloadind and reading geometry from the NYC Open Data API
# https://data.cityofnewyork.us/Housing-Development/Public-Use-Microdata-Areas-PUMA-/cwiz-gcty/data

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/cwiz-gcty?method=export&format=Shapefile'
shapefile = urllib.urlretrieve(url, 'file.gz' )
# !unzip file.gz -d $PUIdata/shapefiles/shapefile_PUMA_NYC
# !ls $PUIdata/shapefiles/shapefile_PUMA_NYC
# Out:
# geo_export_bd2fd15c-479c-4ec4-80a9-e992aaf12623.dbf
# geo_export_bd2fd15c-479c-4ec4-80a9-e992aaf12623.prj
# geo_export_bd2fd15c-479c-4ec4-80a9-e992aaf12623.shp
# geo_export_bd2fd15c-479c-4ec4-80a9-e992aaf12623.shx

# %%
pumashp = gpd.GeoDataFrame.from_file(PUIdata + '/shapefiles/shapefile_PUMA_NYC/geo_export_bd2fd15c-479c-4ec4-80a9-e992aaf12623.shp')
pumashp.puma = pumashp.puma.astype(int)
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry
# 0  POLYGON ((-73.89641133483133 40.90450452082026...
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...
# 4  POLYGON ((-73.95374853778468 40.63858633758547...

# %%
pumashp.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# ### 1.2 Plotting the PUMA NYC regions

# %%
ax = pumashp.plot(color='white', edgecolor='black', lw=2)
ax.axis('off')
plt.title('Public Use Microdata Area (PUMA) Boundaries for New York City')
# Out:
# Text(0.5,1,'Public Use Microdata Area (PUMA) Boundaries for New York City')

# %% [markdown]
# **Figure1:** Public Use Microdata Area (PUMA) Boundaries for New York City.

# %% [markdown]
# ### 2. American Fact Finder data on percentage of houses with broadband internet access
# ### 2.1 Getting data using American Fact Finder (AFF) API:

# %%
#reading in my api key saved in censusAPI.py as
#myAPI = 'XXXXXXXXXXXXXXX'
from censusAPI import myAPI

# %% [markdown]
# **You can find out what are the features that you can query through the API for the annually surveyed data at this url:**
# https://api.census.gov/data/2016/acs/acs1/variables.json

# %%
url = 'https://api.census.gov/data/2016/acs/acs1/variables.json'
response = requests.request('GET', url)
aff1y = json.loads(response.text)

# %%
aff1y.keys()
# Out:
# dict_keys(['variables'])

# %%
#turning things into arrays to enable broadcasting
affkeys = np.array(list(aff1y['variables'].keys()))

# %%
#extracting variables of B28002 that contain "broadband"
[(k, aff1y['variables'][k]['label']) \
for k in affkeys if k.startswith ('B28002') \
and 'Broadband' in aff1y['variables'][k]['label']]
# Out:
# [('B28002_007E',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  ('B28002_004E',
#   'Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  ('B28002_008E',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription')]

# %%
#key for the number of households
keyNhouseholds = 'B28002_001E'
aff1y['variables'][keyNhouseholds]
# Out:
# {'attributes': 'B28002_001M,B28002_001EA',
#  'concept': 'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#  'group': 'B28002',
#  'label': 'Estimate!!Total',
#  'limit': 0,
#  'predicateType': 'int'}

# %%
#key for the number of households with broadband access
keyNBB = 'B28002_004E'
aff1y['variables'][keyNBB]
# Out:
# {'attributes': 'B28002_004M,B28002_004EA',
#  'concept': 'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#  'group': 'B28002',
#  'label': 'Estimate!!Total!!With an Internet subscription!!Broadband of any type',
#  'limit': 0,
#  'predicateType': 'int'}

# %%
# getting the broadband access number of households
url = 'https://api.census.gov/data/2016/acs/acs1?get=' + keyNBB + \
',NAME&for=public%20use%20microdata%20area:*&in=state:36&key=' + myAPI
response = requests.request('GET', url).content
pumaBB = pd.read_csv(io.StringIO(response.decode('utf-8').replace('[','').replace(']','')))

pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state  \
# 0        32607                 St. Lawrence County PUMA, New York     36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        41210        Warren & Washington Counties PUMA, New York     36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
# getting the first row of the table: the total number of households
url = 'https://api.census.gov/data/2016/acs/acs1?get=' + keyNhouseholds + \
',NAME&for=public%20use%20microdata%20area:*&in=state:36&key=' + myAPI
response = requests.request('GET', url).content
pumaPP = pd.read_csv(io.StringIO(response.decode('utf-8').replace('[','').replace(']','')))

pumaPP.head()
# Out:
#    B28002_001E                                               NAME  state  \
# 0        40479                 St. Lawrence County PUMA, New York     36
# 1        67092  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2        51614        Warren & Washington Counties PUMA, New York     36
# 3        44300  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4        61146  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %% [markdown]
# ### 2.2 Generating a feature for the percentage of households with broadband access

# %%
#merge
pumaBB = pumaBB.merge(pumaPP, on='NAME')
pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state_x  \
# 0        32607                 St. Lawrence County PUMA, New York       36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...       36
# 2        41210        Warren & Washington Counties PUMA, New York       36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...       36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...       36
#
#    public use microdata area_x  Unnamed: 4_x  B28002_001E  state_y  \
# 0                          100           NaN        40479       36
# 1                          200           NaN        67092       36
# 2                          300           NaN        51614       36
# 3                          401           NaN        44300       36
# 4                          402           NaN        61146       36
#
#    public use microdata area_y  Unnamed: 4_y
# 0                          100           NaN
# 1                          200           NaN
# 2                          300           NaN
# 3                          401           NaN
# 4                          402           NaN

# %%
pumaBB.columns
# Out:
# Index(['B28002_004E', 'NAME', 'state_x', 'public use microdata area_x',
#        'Unnamed: 4_x', 'B28002_001E', 'state_y', 'public use microdata area_y',
#        'Unnamed: 4_y'],
#       dtype='object')

# %%
#drop
pumaBB.drop(['Unnamed: 4_x', 'state_y','public use microdata area_y', 
             'Unnamed: 4_y'], axis=1, inplace=True)

# %%
pumaBB.head()
# Out:
#    B28002_004E                                               NAME  state_x  \
# 0        32607                 St. Lawrence County PUMA, New York       36
# 1        50811  Clinton, Franklin, Essex & Hamilton Counties P...       36
# 2        41210        Warren & Washington Counties PUMA, New York       36
# 3        36075  Herkimer (North & Central) & Oneida (Outer) Co...       36
# 4        47786  Oneida County (Central)--Greater Utica & Rome ...       36
#
#    public use microdata area_x  B28002_001E
# 0                          100        40479
# 1                          200        67092
# 2                          300        51614
# 3                          401        44300
# 4                          402        61146

# %%
pumaBB.columns
# Out:
# Index(['B28002_004E', 'NAME', 'state_x', 'public use microdata area_x',
#        'B28002_001E'],
#       dtype='object')

# %%
#Rename
pumaBB.columns = ['NBB', 'NAME', 'state', 'public use microdata area',
       'Nhouseholds']
pumaBB.head()
# Out:
#      NBB                                               NAME  state  \
# 0  32607                 St. Lawrence County PUMA, New York     36
# 1  50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2  41210        Warren & Washington Counties PUMA, New York     36
# 3  36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4  47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Nhouseholds
# 0                        100        40479
# 1                        200        67092
# 2                        300        51614
# 3                        401        44300
# 4                        402        61146

# %%
# adding a new column for the percentage of households with broadband access 
# NBB: number of huoseholds with broadband internet
# Nhouseholds: total number of households
# pcBB: percentage of households with broadband access
pumaBB['pcBB'] = pumaBB['NBB'] / pumaBB['Nhouseholds'] * 100
pumaBB.head()
# Out:
#      NBB                                               NAME  state  \
# 0  32607                 St. Lawrence County PUMA, New York     36
# 1  50811  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2  41210        Warren & Washington Counties PUMA, New York     36
# 3  36075  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4  47786  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Nhouseholds       pcBB
# 0                        100        40479  80.552879
# 1                        200        67092  75.733321
# 2                        300        51614  79.842678
# 3                        401        44300  81.433409
# 4                        402        61146  78.150656

# %% [markdown]
# ### 2.3 Comparing it with the AFF published "percentage of households with broadband access"
# #### Dowloaded the the table using this [link](https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?pid=ACS_16_1YR_GCT2801.ST50&prodType=table) and then uploaded it to my PUIdata/ACS folder

# %%
# !unzip $PUIdata/ACS/ACS_16_1YR_GCT2801.ST50.zip -d $PUIdata/ACS/ACS_16_1YR_GCT2801
# !mv $PUIdata/ACS/ACS_16_1YR_GCT2801.ST50.zip $PUIdata/ACS/ACS_16_1YR_GCT2801
# !ls $PUIdata/ACS/ACS_16_1YR_GCT2801
# Out:
# ACS_16_1YR_GCT2801.ST50_metadata.csv  ACS_16_1YR_GCT2801.ST50.zip
# ACS_16_1YR_GCT2801.ST50.txt	      aff_download_readme_ann.txt
# ACS_16_1YR_GCT2801.ST50_with_ann.csv

# %%
bbpc = pd.read_csv(PUIdata + '/ACS/ACS_16_1YR_GCT2801/ACS_16_1YR_GCT2801.ST50_with_ann.csv', skiprows=[0], usecols=['Target Geo Id2', 'Percent', 'Margin of Error'])
bbpc.columns=['public use microdata area', 'Percent', 'Margin of Error']
bbpc['public use microdata area'] = bbpc['public use microdata area']-3600000
bbpc.head()
# Out:
#    public use microdata area  Percent  Margin of Error
# 0                   -3599964     81.7              0.2
# 1                        100     80.6              2.6
# 2                        200     75.7              2.2
# 3                        300     79.8              2.6
# 4                        401     81.4              2.4

# %% [markdown]
# ### 2.4 Checking that the percentage of households with broadband I generated is the same as the one I read in from the manually downloaded table

# %%
comp = pumaBB.merge(bbpc, on='public use microdata area')[['pcBB', 'Percent']]
comp['diff'] = np.abs(comp['pcBB'] - comp['Percent'])
comp.tail()
# Out:
#           pcBB  Percent      diff
# 140  82.579178     82.6  0.020822
# 141  83.841021     83.8  0.041021
# 142  76.787748     76.8  0.012252
# 143  85.546608     85.5  0.046608
# 144  77.770257     77.8  0.029743

# %%
comp.describe()
# Out:
#              pcBB     Percent        diff
# count  145.000000  145.000000  145.000000
# mean    81.845478   81.843448    0.026217
# std      7.063369    7.065358    0.014480
# min     54.932945   54.900000    0.000178
# 25%     77.770257   77.800000    0.012252
# 50%     82.826141   82.800000    0.027230
# 75%     87.305077   87.300000    0.039090
# max     93.404143   93.400000    0.049872

# %% [markdown]
# **The maximum difference in percentages is very small**

# %% [markdown]
# ### 3 Plotting a choropleth of NYC broadband access

# %%
# merge with the PUMA geodataframe
pumashp = pumashp.merge(pumaBB, left_on='puma', right_on='public use microdata area')
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry    NBB  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...  34030
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...  36716
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...  32269
# 4  POLYGON ((-73.95374853778468 40.63858633758547...  44079
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
# 2  NYC-Bronx Community District 10--Co-op City, P...     36
# 3  NYC-Bronx Community District 11--Pelham Parkwa...     36
# 4  NYC-Brooklyn Community District 14--Flatbush &...     36
#
#    public use microdata area  Nhouseholds       pcBB
# 0                       3701        42158  84.275820
# 1                       3702        49817  68.310015
# 2                       3703        44329  82.826141
# 3                       3704        44476  72.553737
# 4                       4015        55953  78.778618

# %%
# plot a choropleth of the percentage of households with broadband access
ax = pumashp.plot(column='pcBB', legend=True, edgecolor='white')
ax.axis('off')
plt.title('Percentage of Households with Broadband Internet Access (PUMA)')
# Out:
# Text(0.5,1,'Percentage of Households with Broadband Internet Access (PUMA)')

# %% [markdown]
# **Figure 2:** A choropleth map showing the percentage of households with broadband internet access distributed at the level of public use microdata areas (PUMAs). We notice how lower and midtown Manhattan have high percentages as they are the center of businesses in the city.

# %% [markdown]
# ### 4. LinkNYC: Assessing whether the locations of the linkNYC stations are supplying internet where it is needed.

# %%
# LinkNYC locations aquired from: https://github.com/fedhere/PUI2018_fb55/tree/master/HW7_fb55
# !curl -O 'https://raw.githubusercontent.com/fedhere/PUI2018_fb55/master/HW7_fb55/linkNYClocations.csv'
# !mv linkNYClocations.csv $PUIdata

# %%
linkNYC = pd.read_csv(PUIdata + '/linkNYClocations.csv', index_col=0)
linkNYC.head()
# Out:
#       link_site  longitude  date_link_   latitude
# 0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4  bk-01-125268 -73.953439  2017-03-31  40.728133

# %%
linkNYC.shape
# Out:
# (1414, 4)

# %% [markdown]
# ### 4.2 Creating a geodataframe

# %%
# combine lat and lon to one column
linkNYC['lonlat'] = list(zip(linkNYC['longitude'],linkNYC['latitude']))
# create Point Geometry based on lonlat column
linkNYC['geometry'] = linkNYC[['lonlat']].applymap(lambda x: shapely.geometry.Point(x))
linkNYC.head()
# Out:
#       link_site  longitude  date_link_   latitude  \
# 0  bk-01-138951 -73.942489  2017-07-01  40.701668
# 1  bk-01-109091 -73.942169  2017-07-01  40.701542
# 2  bk-01-143982 -73.942239  2017-07-01  40.701930
# 3  bk-01-109262 -73.942918  2017-04-28  40.705060
# 4  bk-01-125268 -73.953439  2017-03-31  40.728133
#
#                             lonlat                                  geometry
# 0      (-73.94248859, 40.70166753)          POINT (-73.94248859 40.70166753)
# 1  (-73.9421692831, 40.7015421938)      POINT (-73.9421692831 40.7015421938)
# 2  (-73.9422392385, 40.7019303439)  POINT (-73.94223923850001 40.7019303439)
# 3      (-73.94291758, 40.70506042)          POINT (-73.94291758 40.70506042)
# 4          (-73.953439, 40.728133)              POINT (-73.953439 40.728133)

# %%
linkNYC = gpd.GeoDataFrame(linkNYC)
type(linkNYC)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
linkNYC.crs = from_epsg(4326)
linkNYC.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %% [markdown]
# ### 4.3 Plotting the location of the linkNYC stations on top of a choropleth of broadband access percentage in 5 equal intervals

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
pumashp.plot(ax=ax, column='pcBB', cmap='bone', scheme='equal_interval', edgecolor='k', legend=True)
linkNYC.plot(ax=ax, c=linkNYC.date_link_, marker='o', cmap='OrRd', markersize=4)
ax.axis('off')
ax.get_legend().set_bbox_to_anchor((.2, .9))
plt.title('Location of linkNYC Stations and Percentage of Households with Broadband Internet Accces')
# Out:
# Text(0.5,1,'Location of linkNYC Stations and Percentage of Households with Broadband Internet Accces')

# %% [markdown]
# **Figure 3:** The location of linkNYC stations plotted on a choropleth map of the percentage of households with broadband internet access distributed at the level of public use microdata areas (PUMAs). We notice a higher station concentration in Manhattan -where the broadband access percentage is already very high. Some of the locations with low broadband access percentages do have a linkNYC station closeby, however we can clearly notice that the majority of areas with lower access lack linkNYC stations.

# %% [markdown]
# ### 5 Finding the number of linkNYC locations per person by PUMA
# #### 5.1 Getting the total population using AFF API from ACS

# %%
# getting the UNWEIGHTED SAMPLE COUNT OF THE POPULATION 
# https://api.census.gov/data/2016/acs/acs1/groups/B00001.html
keyPop = 'B00001_001E'
url = 'https://api.census.gov/data/2016/acs/acs1?get=' + keyPop + \
',NAME&for=public%20use%20microdata%20area:*&in=state:36&key=' + myAPI
response = requests.request('GET', url).content
pumaPop = pd.read_csv(io.StringIO(response.decode('utf-8').replace('[','').replace(']','')))

pumaPop.head()
# Out:
#    B00001_001E                                               NAME  state  \
# 0         3075                 St. Lawrence County PUMA, New York     36
# 1         4356  Clinton, Franklin, Essex & Hamilton Counties P...     36
# 2         2736        Warren & Washington Counties PUMA, New York     36
# 3         2722  Herkimer (North & Central) & Oneida (Outer) Co...     36
# 4         2874  Oneida County (Central)--Greater Utica & Rome ...     36
#
#    public use microdata area  Unnamed: 4
# 0                        100         NaN
# 1                        200         NaN
# 2                        300         NaN
# 3                        401         NaN
# 4                        402         NaN

# %%
pumaPop.columns
# Out:
# Index(['B00001_001E', 'NAME', 'state', 'public use microdata area',
#        'Unnamed: 4'],
#       dtype='object')

# %%
pumaPop.drop(['NAME', 'state', 'Unnamed: 4'], axis=1, inplace=True)
pumaPop.columns = ['Population', 'public use microdata area']
pumaPop.head()
# Out:
#    Population  public use microdata area
# 0        3075                        100
# 1        4356                        200
# 2        2736                        300
# 3        2722                        401
# 4        2874                        402

# %%
# merge with the geodataframe
pumashp = pumashp.merge(pumaPop, on='public use microdata area')
pumashp.head(2)
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
#
#                                             geometry    NBB  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...  34030
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
#
#    public use microdata area  Nhouseholds       pcBB  Population
# 0                       3701        42158  84.275820        1517
# 1                       3702        49817  68.310015        1959

# %% [markdown]
# ### 5.2 Finding the number of station per 100 people per PUMA
# ### Perform a spatial join

# %%
# convert coordinates 
pumashp.to_crs(epsg=2263)
linkNYC.to_crs(epsg=2263)
pumashp.crs, linkNYC.crs
# Out:
# ({'init': 'epsg:4326'}, {'init': 'epsg:4326', 'no_defs': True})

# %%
pumalink = gpd.sjoin(pumashp, linkNYC, how='left').groupby('puma')['link_site'].count().reset_index()
pumalink.head()
# Out:
# Warning: CRS does not match!
#    puma  link_site
# 0  3701          1
# 1  3702          0
# 2  3703          0
# 3  3704          0
# 4  3705          1

# %%
pumashp = pumashp.merge(pumalink, on='puma')
pumashp.head()
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
# 2  3703  2.670137e+08  304071.257466
# 3  3704  1.062129e+08   47970.901277
# 4  4015  8.105438e+07   50007.415493
#
#                                             geometry    NBB  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...  34030
# 2  (POLYGON ((-73.78833349834532 40.8346671297593...  36716
# 3  POLYGON ((-73.84792614069238 40.8713422330779,...  32269
# 4  POLYGON ((-73.95374853778468 40.63858633758547...  44079
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
# 2  NYC-Bronx Community District 10--Co-op City, P...     36
# 3  NYC-Bronx Community District 11--Pelham Parkwa...     36
# 4  NYC-Brooklyn Community District 14--Flatbush &...     36
#
#    public use microdata area  Nhouseholds       pcBB  Population  link_site
# 0                       3701        42158  84.275820        1517          1
# 1                       3702        49817  68.310015        1959          0
# 2                       3703        44329  82.826141        1305          0
# 3                       3704        44476  72.553737        1882          0
# 4                       4015        55953  78.778618        2515          3

# %%
pumashp['linkNYCp100p'] = pumashp['link_site'] * 100 / pumashp['Population']
pumashp.head(2)
# Out:
#    puma    shape_area     shape_leng  \
# 0  3701  9.792852e+07   53227.144461
# 1  3702  1.889860e+08  106050.002302
#
#                                             geometry    NBB  \
# 0  POLYGON ((-73.89641133483133 40.90450452082026...  35529
# 1  POLYGON ((-73.8442314689986 40.86942035096838,...  34030
#
#                                                 NAME  state  \
# 0  NYC-Bronx Community District 8--Riverdale, Fie...     36
# 1  NYC-Bronx Community District 12--Wakefield, Wi...     36
#
#    public use microdata area  Nhouseholds       pcBB  Population  link_site  \
# 0                       3701        42158  84.275820        1517          1
# 1                       3702        49817  68.310015        1959          0
#
#    linkNYCp100p
# 0       0.06592
# 1       0.00000

# %%
pumashp['linkNYCp100p'].describe()
# Out:
# count    55.000000
# mean      1.565892
# std       2.933074
# min       0.000000
# 25%       0.000000
# 50%       0.538358
# 75%       1.646966
# max      15.141540
# Name: linkNYCp100p, dtype: float64

# %% [markdown]
# ### 5.3 Plotting the linkNYC locations on top of a choropleth of number of stations per 100 people in 10 equal intervals

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
pumashp.plot(ax=ax, column='linkNYCp100p', cmap='bone', scheme='quantiles', k=10, edgecolor='grey', legend=True)
linkNYC.plot(ax=ax, c=linkNYC.date_link_, marker='o', cmap='OrRd', markersize=4)
ax.axis('off')
ax.get_legend().set_bbox_to_anchor((.2, .9))
plt.title('Location of linkNYC Stations and the Number of Stations per 100 people')
# Out:
# Text(0.5,1,'Location of linkNYC Stations and the Number of Stations per 100 people')

# %% [markdown]
# **Figure 4:** The location of linkNYC stations plotted on a choropleth map showing the number of stations per 100 people. We notice that the highest concentration of stations per 100 people is around midtown Manhattan. All of the areas outside Manhattan show a very low concentration - less than 3 stations per 100 people.

# %% [markdown]
# ### 5.4 Plotting the Spatial Lag Deciles that describe the impact of linkNYC in providing access where needed.

# %%
# Export shapefile
# %mkdir Output
path = 'Output/pumashp.shp'
pumashp.to_file(path)

# %%
# Spatial weights
# Contiguity: Queen Weights
qW_linkNYC = ps.queen_from_shapefile(path)

# %%
# Matrix of Weights
Wmatrix, ids = qW_linkNYC.full()
Wmatrix
plt.imshow(Wmatrix)

# %%
# change the matrix to be row-standardized
qW_linkNYC.transform = 'r'

# %%
# Spatial lag
linkNYC_lag = ps.lag_spatial(qW_linkNYC, pumashp.linkNYCp100p)

# %%
# Create Quantiles for maping
linkNYC_lag_Q10 = ps.Quantiles(linkNYC_lag, k=10)
linkNYC_lag_Q10
# Out:
#               Quantiles
#
# Lower          Upper            Count
# =====================================
#         x[i] <= 0.017               6
# 0.017 < x[i] <= 0.211               5
# 0.211 < x[i] <= 0.463               6
# 0.463 < x[i] <= 0.578               5
# 0.578 < x[i] <= 0.788               6
# 0.788 < x[i] <= 0.989               5
# 0.989 < x[i] <= 1.193               6
# 1.193 < x[i] <= 2.997               5
# 2.997 < x[i] <= 5.159               5
# 5.159 < x[i] <= 9.704               6

# %%
# Map the monthly rides lag
fig, ax = plt.subplots()
pumashp.assign(cl=linkNYC_lag_Q10.yb).plot(column='cl', categorical=True, k=10, cmap='hot_r',\
                                          linewidth=0.1, ax=ax, edgecolor='white', legend=True)
ax.axis('off')
plt.title('LinkNYC per 100 Persons Spatial Lag Deciles')
ax.get_legend().set_bbox_to_anchor((.2, .9))

# %% [markdown]
# **Figure 5:** Plotting the Spatial Lag Deciles we notice that the variable which is the number of LinkNYC stations per 100 people show similar values in different nighborhoods in midtown and lower Manhattan (high spatial correlation > 9). On the other hand, as we move away from these two areas we notice how the values of the variable become different indicating low spatial correlation. For example two adjacent areas one colored deep red and the other yellow show a very low spatial correlation. These disparities in the value of our variable in different areas indicate the need for a more just distribution of the LinkNYC stations across the different boroughs.
